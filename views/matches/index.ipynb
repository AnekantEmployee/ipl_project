# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("head_to_head.csv")

# %%
df
# Out:
#    Unnamed: 0       id  season         city        date match_type  \
# 0          32  1304079    2022  Navi Mumbai  2022-04-21     League
# 1          33  1304105    2022       Mumbai  2022-05-12     League
# 2          34  1359486    2023       Mumbai  2023-04-08     League
# 3          35  1359523    2023      Chennai  2023-05-06     League
# 4          36  1426267    2024       Mumbai  2024-04-14     League
#
#     player_of_match                                     venue  \
# 0  Mukesh Choudhary        Dr DY Patil Sports Academy, Mumbai
# 1           DR Sams                  Wankhede Stadium, Mumbai
# 2         RA Jadeja                  Wankhede Stadium, Mumbai
# 3       M Pathirana  MA Chidambaram Stadium, Chepauk, Chennai
# 4       M Pathirana                  Wankhede Stadium, Mumbai
#
#                  team1                team2  ... toss_decision  \
# 0       Mumbai Indians  Chennai Super Kings  ...         field
# ...

# %% [markdown]
# Overall

# %%
len(df)
# Out:
# 34

# %%
df['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore'],
#       dtype=object)

# %%
won_by_team1 = len(df[df['winner'] == 'Royal Challengers Bangalore'])
won_by_team2 = len(df[df['winner'] == 'Kolkata Knight Riders'])
drawn = len(df[df['winner'].isnull()])

print(won_by_team1)
print(won_by_team2)
print(drawn)
# Out:
# 14
# 20
# 0

# %%
home_won_by_team1 = len(df[(df['winner'] == 'Royal Challengers Bangalore') & (df['city'] == 'Bangalore')])
home_loss_by_team1 = len(df[(df['winner'] == 'Kolkata Knight Riders') & (df['city'] == 'Bangalore')])
away_won_by_team1 = len(df[(df['winner'] == 'Royal Challengers Bangalore') & (df['city'] != 'Bangalore')])
away_loss_by_team1 = len(df[(df['winner'] == 'Kolkata Knight Riders') & (df['city'] != 'Bangalore')])

print(home_won_by_team1)
print(home_loss_by_team1)
print(away_won_by_team1)
print(away_loss_by_team1)
# Out:
# 4
# 4
# 10
# 16

# %%
df[(df['winner'] == 'Kolkata Knight Riders') & (df['result'] == 'runs')].sort_values(by='result_margin', ascending=False).iloc[0]['result_margin']
# Out:
# np.float64(140.0)

# %%
df[df['winner'] == 'Royal Challengers Bangalore'].sort_values(by='result_margin', ascending=False).iloc[0]['result_margin']
# Out:
# np.float64(82.0)

# %%
df.iloc[1]
# Out:
# Unnamed: 0                                   1
# id                                      336010
# season                                 2007/08
# city                                   Kolkata
# date                                2008-05-08
# match_type                              League
# player_of_match                     SC Ganguly
# venue                             Eden Gardens
# team1                    Kolkata Knight Riders
# team2              Royal Challengers Bangalore
# toss_winner              Kolkata Knight Riders
# toss_decision                              bat
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                              5.0
# target_runs                              130.0
# target_overs                              16.0
# super_over                                   N
# method                                  normal
# umpire1                              Asad Rauf
# ...

# %%
df[df['season'] == '2017'].transpose()
# Out:
#                                           18                           19
# Unnamed: 0                                18                           19
# id                                   1082617                      1082636
# season                                  2017                         2017
# city                                 Kolkata                    Bangalore
# date                              2017-04-23                   2017-05-07
# match_type                            League                       League
# player_of_match              NM Coulter-Nile                    SP Narine
# venue                           Eden Gardens        M Chinnaswamy Stadium
# team1                  Kolkata Knight Riders  Royal Challengers Bangalore
# team2            Royal Challengers Bangalore        Kolkata Knight Riders
# toss_winner      Royal Challengers Bangalore        Kolkata Knight Riders
# toss_decision                          field                        field
# ...

# %%
highest_score = df[((df['toss_winner'] == 'Royal Challengers Bangalore') & (df['toss_decision'] == 'bat')) | ((df['toss_winner'] != 'Royal Challengers Bangalore') & (df['toss_decision'] == 'field'))].sort_values('target_runs', ascending=False).iloc[0]['target_runs']
highest_score2 = df[((df['toss_winner'] == 'Royal Challengers Bangalore') & (df['toss_decision'] == 'field')) | ((df['toss_winner'] != 'Royal Challengers Bangalore') & (df['toss_decision'] == 'bat'))]

# %%
highest_score2
# Out:
#     Unnamed: 0       id   season       city        date match_type  \
# 0            0   335982  2007/08  Bangalore  2008-04-18     League
# 1            1   336010  2007/08    Kolkata  2008-05-08     League
# 2            2   392199     2009     Durban  2009-04-29     League
# 3            3   392221     2009  Centurion  2009-05-12     League
# 5            5   419148  2009/10  Bangalore  2010-04-10     League
# 6            6   501222     2011    Kolkata  2011-04-22     League
# 7            7   501255     2011  Bangalore  2011-05-14     League
# 8            8   548315     2012  Bangalore  2012-04-10     League
# 9            9   548344     2012    Kolkata  2012-04-28     League
# 10          10   598008     2013  Bangalore  2013-04-11     League
# 12          12   729299     2014        NaN  2014-04-24     League
# 13          13   734027     2014    Kolkata  2014-05-22     League
# 14          14   829713     2015    Kolkata  2015-04-11     League
# ...

# %%
lowest_score = df[((df['toss_winner'] == 'Royal Challengers Bangalore') & (df['toss_decision'] == 'bat')) | ((df['toss_winner'] != 'Royal Challengers Bangalore') & (df['toss_decision'] == 'field'))].sort_values('target_runs', ascending=True).iloc[0]['target_runs']

# %%
print(highest_score, highest_score2)
print(lowest_score)
# Out:
# 214.0     Unnamed: 0       id   season       city        date match_type  \
# 0            0   335982  2007/08  Bangalore  2008-04-18     League
# 1            1   336010  2007/08    Kolkata  2008-05-08     League
# 2            2   392199     2009     Durban  2009-04-29     League
# 3            3   392221     2009  Centurion  2009-05-12     League
# 5            5   419148  2009/10  Bangalore  2010-04-10     League
# 6            6   501222     2011    Kolkata  2011-04-22     League
# 7            7   501255     2011  Bangalore  2011-05-14     League
# 8            8   548315     2012  Bangalore  2012-04-10     League
# 9            9   548344     2012    Kolkata  2012-04-28     League
# 10          10   598008     2013  Bangalore  2013-04-11     League
# 12          12   729299     2014        NaN  2014-04-24     League
# 13          13   734027     2014    Kolkata  2014-05-22     League
# 14          14   829713     2015    Kolkata  2015-04-11     League
# ...
